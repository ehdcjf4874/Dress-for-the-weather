# %%
#https://kauth.kakao.com/oauth/authorize?client_id={REST_API 앱키를 입력하세요}&response_type=code&redirect_uri=https://localhost.com
import requests
import json

url = "https://kauth.kakao.com/oauth/token"

data = {
    "grant_type" : "authorization_code",
    "client_id" : "63435f91272f6e20e1cf693b27987220",
    "redirect_uri" : "https://localhost.com",
    "code"         : "s70CuG2e8ziqPt_3ZH2GxiNj_7ZSgJjSsO3D3hdTqQCylFNg70diNDSAyaw60AJKswKBZQo9cxgAAAF3FFoJWA"
    
}
response = requests.post(url, data=data)

tokens = response.json()

print(tokens)
# Out:
# {'error': 'invalid_grant', 'error_description': 'authorization code not found for code=s70CuG2e8ziqPt_3ZH2GxiNj_7ZSgJjSsO3D3hdTqQCylFNg70diNDSAyaw60AJKswKBZQo9cxgAAAF3FFoJWA', 'error_code': 'KOE320'}

# %%
# 카카오톡 인증
# https://developers.kakao.com/docs/restapi/tool
# 해당 사이트에서 로그인 후 'Access token'을 얻어오세요
kcreds = {
    "access_token" : "CuSdUKz81kUTUdmoXC-Pbrz5RD5NQDZVXgIRrwopb9QAAAF3FFqACQ"
}
kheaders = {
    "Authorization": "Bearer " + kcreds.get('access_token')
}

# %%
url = "https://kauth.kakao.com/oauth/token"
data = {
    "grant_type" : "refresh_token",
    "client_id"  : "63435f91272f6e20e1cf693b27987220",
    "refresh_token" : "kJKnbYdkHukXWGNt-VDTMWLFZCqGilcv0WkXrAopb9QAAAF3FFqABw"
}
response = requests.post(url, data=data)

print(response.json())
# Out:
# {'error': 'invalid_grant', 'error_description': 'expired_or_invalid_refresh_token', 'error_code': 'KOE322'}

# %%
# 네이버 인증
# https://developers.naver.com/apps
# 해당 사이트에서 로그인 후 "Cliend ID"와 "Client Secret"을 얻어오세요
ncreds = {
    "client_id": "xQFBAtUi_W9jQk8D5984",      
    "client_secret" : "z9d5wF4IdL"
}
nheaders = {
    "X-Naver-Client-Id" : ncreds.get('client_id'),
    "X-Naver-Client-Secret" : ncreds.get('client_secret')
}

# %%
#google Geolocation API 사용
import os
import requests
from dotenv import load_dotenv
import math
load_dotenv(verbose=True)

LOCATION_API_KEY = os.getenv('LOCATION_API_KEY')

url = f'https://www.googleapis.com/geolocation/v1/geolocate?key=AIzaSyDqrO5yr7HQebIT62pWsNhF2xRGxynAuXQ'
data = {
    'considerIp': True,
}
#현재 좌표 구하기
result = requests.post(url, data)

#print(result.text)


NX = 149            ## X축 격자점 수
NY = 253            ## Y축 격자점 수

Re = 6371.00877     ##  지도반경
grid = 5.0          ##  격자간격 (km)
slat1 = 30.0        ##  표준위도 1
slat2 = 60.0        ##  표준위도 2
olon = 126.0        ##  기준점 경도
olat = 38.0         ##  기준점 위도
xo = 210 / grid     ##  기준점 X좌표
yo = 675 / grid     ##  기준점 Y좌표
first = 0

if first == 0 :
    PI = math.asin(1.0) * 2.0
    DEGRAD = PI/ 180.0
    RADDEG = 180.0 / PI


    re = Re / grid
    slat1 = slat1 * DEGRAD
    slat2 = slat2 * DEGRAD
    olon = olon * DEGRAD
    olat = olat * DEGRAD

    sn = math.tan(PI * 0.25 + slat2 * 0.5) / math.tan(PI * 0.25 + slat1 * 0.5)
    sn = math.log(math.cos(slat1) / math.cos(slat2)) / math.log(sn)
    sf = math.tan(PI * 0.25 + slat1 * 0.5)
    sf = math.pow(sf, sn) * math.cos(slat1) / sn
    ro = math.tan(PI * 0.25 + olat * 0.5)
    ro = re * sf / math.pow(ro, sn)
    first = 1

def mapToGrid(lat, lon, code = 0 ):
    ra = math.tan(PI * 0.25 + lat * DEGRAD * 0.5)
    ra = re * sf / pow(ra, sn)
    theta = lon * DEGRAD - olon
    if theta > PI :
        theta -= 2.0 * PI
    if theta < -PI :
        theta += 2.0 * PI
    theta *= sn
    x = (ra * math.sin(theta)) + xo
    y = (ro - ra * math.cos(theta)) + yo
    x = int(x + 1.5)
    y = int(y + 1.5)
    return x, y

#현재좌표의 격자구하기
location=(mapToGrid(float(result.json().get('location').get('lat')), float(result.json().get('location').get('lng'))))

import requests
import json
import datetime
vilage_weather_url = "http://apis.data.go.kr/1360000/VilageFcstInfoService/getUltraSrtNcst?"

service_key = "PeFFwEmZoRDnl%2F%2Fy%2Bml%2BDP%2F%2BoVukyGKlKB9vqyj1DMvaZa0SAr3x9N8OPY1tX0CymjTcRy3h2VlLxMHS8249Xg%3D%3D"

today = datetime.datetime.today()
base_date = today.strftime("%Y%m%d") # "20200214" == 기준 날짜
base_time = int(today.strftime("%H%M")) # 날씨 값

#현재시각 설정
#제공시간은 각 시각 40분이후
if (40<=base_time<140):
     base_time ="0000"
elif (140<=base_time<240):
    base_time="0100"
elif (240<=base_time<340):
    base_time="0200"
elif (340<=base_time<440):
    base_time="0300"
elif (440<=base_time<540):
    base_time="0400"
elif (540<=base_time<640):
    base_time="0500"
elif (640<=base_time<740):
     base_time="0600"
elif (740<=base_time<840):
     base_time="0700"
elif (840<=base_time<940):
     base_time="0800"
elif (940<=base_time<1040):
     base_time="0900"
elif (1040<=base_time<1140):
     base_time="1000"
elif (1140<=base_time<1240):
     base_time="1100"
elif (1240<=base_time<1340):
     base_time="1200"
elif (1340<=base_time<1440):
     base_time="1300"
elif (1440<=base_time<1540):
     base_time="1400"
elif (1540<=base_time<1640):
     base_time="1500"
elif (1640<=base_time<1740):
     base_time="1600"
elif (1740<=base_time<1840):
     base_time="1700"
elif (1840<=base_time<1940):
     base_time="1800"
elif (1940<=base_time<2040):
     base_time="1900"
elif (2040<=base_time<2140):
     base_time="2000"
elif (2140<=base_time<2240):
     base_time="2100"
elif (2240<=base_time<2340):
     base_time="2200"
else :
    base_time="2300"


nx = str(location[0])
ny = str(location[1])

payload = "serviceKey=" + service_key + "&" +\
    "dataType=json" + "&" +\
    "base_date=" + base_date + "&" +\
    "base_time=" + base_time + "&" +\
    "nx=" + nx + "&" +\
    "ny=" + ny


res = requests.get(vilage_weather_url + payload)

items = res.json().get('response').get('body').get('items')

data = dict()
data['date'] = today.strftime("%Y-%m-%d")
data['time'] = base_time

weather_data = dict()
for item in items['item']:
    # 기온
    if item['category'] == 'T1H':
        weather_data['tmp'] = item['obsrValue']
        weather_data['tmp']=float(weather_data['tmp'])
        #기온에 따른 옷차림
        if weather_data['tmp']<=4:
            weather_clothes = "패딩,두꺼운 코트,목도리,기모제품 (최대한 많이 껴입는 것이 좋음)"
        elif 5<=weather_data['tmp']<=8:
            weather_clothes = "코트,니트,히트텍,청바지,레깅스 (겹쳐입기 필수!)"
        elif 9<=weather_data['tmp']<=11:
            weather_clothes = "점퍼,트렌치코트,야상,니트,스타킹,청바지,면바지 (아우터 안에 가디건 입기)"
        elif 12<=weather_data['tmp']<=16:
            weather_clothes = "점퍼,가디건,맨투맨,야상,니트,스타킹,면바지,청바지"
        elif 17<=weather_data['tmp']<=19:
            weather_clothes = "얇은니트,가디건,맨투맨,얇은점퍼,면바지,청바지"
        elif 20<=weather_data['tmp']<=22:
            weather_clothes = "얇은가디건,긴팔티,면바지,청바지"
        elif 23<=weather_data['tmp']<27:
            weather_clothes = "반팔,얇은티셔츠,반바지,면바지"
        else:
            weather_clothes = "민소매(박스),반팔,반바지,치마"
        weather_data['tmp']=str(weather_data['tmp'])
    
    
    # 기상상태
    if item['category'] == 'PTY':
        
        weather_code = item['obsrValue']
        
        if weather_code == '1':
            weather_state = '비'
        elif weather_code == '2':
            weather_state = '비/눈'
        elif weather_code == '3':
            weather_state = '눈'
        elif weather_code == '4':
            weather_state = '소나기'
        else:
            weather_state = '없음'
        
        weather_data['code'] = weather_code
        weather_data['state'] = weather_state
weather_data['clothes'] = weather_clothes
data['weather'] = weather_data
data['weather']

dust_url = "http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureLIst?"

service_key = "PeFFwEmZoRDnl%2F%2Fy%2Bml%2BDP%2F%2BoVukyGKlKB9vqyj1DMvaZa0SAr3x9N8OPY1tX0CymjTcRy3h2VlLxMHS8249Xg%3D%3D"

item_code_pm10 = "PM10"
item_code_pm25 = "PM25"

data_gubun = "HOUR"
search_condition = "WEEK"

payload = "serviceKey=" + service_key + "&" +\
    "dataType=json" + "&" +\
    "dataGubun=" + data_gubun + "&" +\
    "searchCondition=" + search_condition  + "&" +\
    "itemCode="

# pm10 pm2.5 수치 가져오기
pm10_res = requests.get(dust_url + payload + item_code_pm10)
pm25_res = requests.get(dust_url + payload + item_code_pm25)

# xml 파싱하기
import xml.etree.ElementTree as elemTree

pm10_tree = elemTree.fromstring(pm10_res.text)
pm25_tree = elemTree.fromstring(pm25_res.text)

dust_data = dict()
for tree in [pm10_tree, pm25_tree]:
    item = tree.find("body").find("items").find("item")
    code = item.findtext("itemCode")
    value = int(item.findtext("chungbuk"))
    
    dust_data[code] = {'value' : value}

# 결과 값
dust_data
# {'PM10': {'value': 94}, 'PM2.5': {'value': 71}}

# PM10 미세먼지 30 80 150
pm10_value = dust_data.get('PM10').get('value')

if pm10_value <= 30:
    pm10_state = "좋음"
elif pm10_value <= 80:
    pm10_state = "보통"
elif pm10_value <= 150:
    pm10_state = "나쁨"
else:
    pm10_state = "매우나쁨"

pm25_value = dust_data.get('PM2.5').get('value')
# PM2.5 초미세먼지 15 35 75
if pm25_value <= 15:
    pm25_state = "좋음"
elif pm25_value <= 35:
    pm25_state = "보통"
elif pm25_value <= 75:
    pm25_state = "나쁨"
else:
    pm25_state = "매우나쁨"

# 미세먼지가 나쁜 상태인지(1)/아닌지(0)
if pm10_value > 80 or  pm25_value > 75:
    dust_code = "1"
else:
    dust_code = "0"

dust_data.get('PM10')['state'] = pm10_state

dust_data.get('PM2.5')['state'] = pm25_state

dust_data['code'] = dust_code

data['dust'] = dust_data
data['dust']
#{
# 'PM10': {'value': 94, 'state': '나쁨'},
# 'PM2.5': {'value': 71, 'state': '나쁨'}
#}

low_clothes = "패딩,코트,목도리,기모".split(',')
mid_clothes1 = "코트,니트,히트텍,청바지,레깅스".split(',')
mid_clothes2 = "점퍼,트렌치코트,야상,니트,스타킹,청바지,면바지".split(',')
mid_clothes3 = "점퍼,가디건,맨투맨,야상,니트,스타킹,면바지,청바지".split(',')
mid_clothes4 = "얇은니트,가디건,맨투맨,얇은점퍼,면바지,청바지".split(',')
mid_clothes5 = "얇은가디건,긴팔티,면바지,청바지".split(',')
mid_clothes6 = "반팔,얇은티셔츠,반바지,면바지".split(',')
high_clothes = "민소매,반팔,반바지,치마".split(',')


# 경우 1 : 기온이 낮을 때  => 기온이 낮을 때 옷 3개 추천
# 경우 2 : 기온이 높을 때   => 기온이 높을 때 옷 3개 추천
# 경우 3 : 기온이 적당할 때  => 기온이 적당할 때 옷 3개 추천

# weather_state
if float(data.get('weather').get('tmp')) <=4:
    weather_state = '1'
elif 5<=float(data.get('weather').get('tmp')) <=8:
    weather_state = '2'
elif 9<=float(data.get('weather').get('tmp')) <=11:
    weather_state = '3'
elif 12<=float(data.get('weather').get('tmp')) <=16:
    weather_state = '4'
elif 17<=float(data.get('weather').get('tmp')) <=19:
    weather_state = '5'
elif 20<=float(data.get('weather').get('tmp')) <=22:
    weather_state = '6'
elif 23<=float(data.get('weather').get('tmp')) <=27:
    weather_state = '7'
else:
    weather_state = '8'


import random
# random.sample(x, k=len(x)) 무작위로 리스트 섞기

clothes_list = None

# 경우 1, 2, 3
if weather_state == '1':
    clothes_list = random.sample(low_clothes, k=len(low_clothes))
elif weather_state == '2':
    clothes_list = random.sample(mid_clothes1, k=len(mid_clothes1))
elif weather_state == '3':
    clothes_list = random.sample(mid_clothes2, k=len(mid_clothes2))
elif weather_state == '4':
    clothes_list = random.sample(mid_clothes3, k=len(mid_clothes3))
elif weather_state == '5':
    clothes_list = random.sample(mid_clothes4, k=len(mid_clothes4))
elif weather_state == '6':
    clothes_list = random.sample(mid_clothes5, k=len(mid_clothes5))
elif weather_state == '7':
    clothes_list = random.sample(mid_clothes6, k=len(mid_clothes6))
else:
    clothes_list = random.sample(high_clothes, k=len(high_clothes))

clothes_list
# ['쌀국수', '굴', '콩나물국밥', '마라탕', '고등어']

import urllib
# urllib.parse.quote(query) URL에서 검색어를 인코딩하기 위한 라이브러리

# 네이버 쇼핑 검색 주소
naver_local_url = "https://openapi.naver.com/v1/search/shop.json?"

# 검색에 사용될 파라미터
# 정렬 sort : 리뷰순(comment)
# 검색어 query : 인코딩된 문자열
params_format = "sort=comment&query="


# 추천된 맛집을 담을 리스트
recommands = []
print(clothes_list)
for clothes in clothes_list:
    # 검색어 지정
    query = clothes
    # 지역검색 요청 파라메터 설정
    params = "sort=sim" \
              + "&query=" + query \
              + "&display=" + '5'
    
    # 검색
    # headers : 네이버 인증 정보
    res = requests.get(naver_local_url + params, headers=nheaders)
    
    # 맛집 검색 결과
    result_list = res.json().get('items')
    
    # 경우 1,2 처리
    # 해당 음식 검색 결과에서 가장 상위를 가져옴
    if result_list:
        recommands.append(result_list[0])
        # 3개를 찾았다면 검색 중단
        if len(recommands) >= 3:
            break

#카카오 맵 api을 활용하여 현재좌표를 주로소 변환            
import requests
import json
import pandas as pd

url = "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=%s&y=%s"%(str(result.json().get('location').get('lng')),str(result.json().get('location').get('lat')))
headers = {"Authorization": "KakaoAK 63435f91272f6e20e1cf693b27987220"}
api_test = requests.get(url,headers=headers)
url_text = json.loads(api_test.text)
print(url_text)

import json

# 카카오톡 URL 주소
kakaotalk_template_url = "https://kapi.kakao.com/v2/api/talk/memo/default/send"

# 날씨 상세 정보 URL
weather_url = "https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8"

# 날씨 정보 만들기 
text = f"""\
#%s 날씨 정보 ({data['date']}) 
기준시간 : {data['time']}
기온 : {data['weather']['tmp']}
기우  : {data['weather']['state']}
미세먼지 : {data['dust']['PM10']['value']} {data['dust']['PM10']['state']}
초미세먼지 : {data['dust']['PM2.5']['value']} {data['dust']['PM2.5']['state']}
기온에 따른 옷차림 : {data['weather']['clothes']}
""" % url_text['documents'][0]['address_name']

# 텍스트 템플릿 형식 만들기
template = {
  "object_type": "text",
  "text": text,
  "link": {
    "web_url": weather_url,
    "mobile_web_url": weather_url
  },
  "button_title": "날씨 상세보기"
}

# JSON 형식 -> 문자열 변환
payload = {
    "template_object" : json.dumps(template)
}

# 카카오톡 보내기
res = requests.post(kakaotalk_template_url, data=payload, headers=kheaders)

if res.json().get('result_code') == 0:
    print('메시지를 성공적으로 보냈습니다.')
    
else:
    print('메시지를 성공적으로 보내지 못했습니다. 오류메시지 : ' + str(res.json()))
    
# 리스트 템플릿 형식 만들기
contents = []
template = {
    "object_type" : "list",
    "header_title" : "현재 날씨에 따른 옷차림 추천",
    "header_link" : {
        "web_url": weather_url,
        "mobile_web_url" : weather_url
    },
    "contents" : contents,
    "buttons" : [
        {
            "title" : "날씨 정보 상세보기",
            "link" : {
                "web_url": weather_url,
                "mobile_web_url" : weather_url
            }
        }
    ],
}

# contents 만들기
for place in recommands:
    title = place.get('title')  # 장소 이름
    # title : 태극쿵푸<b>마라탕</b>
    # html 태그 제거
    title = title.replace('<b>','').replace('</b>','')
    
    lprice = place.get('lprice') #최저가 정보
    hpirce = place.get('hprice') #최고가 정보
    brand = place.get('brand') # 상품을 판매하는 쇼핑몰의 상호
    link = place.get('link')  # 검색결과 문서의 하이퍼텍스트 link

    # 각 장소를 클릭할 때 네이버 검색으로 연결해주기 위해 작성된 코드
    title_as = urllib.parse.quote(title)
    query = "query=" + title_as

    # 장소 카테고리가 카페이면 카페 이미지
    # 이외에는 음식 이미지
   
    image_url = place.get('image') # 썸네일 이미지의 url

    
    # 카카오톡 리스트 템플릿 형식에 맞춰줍니다.
    content = {
        "title": title,
        "description": ' '.join(brand.split()),
        "image_url": image_url,
        "image_width": 50, "image_height": 50,
        "link": {
            "web_url": "https://search.naver.com/search.naver?" + query,
            "mobile_web_url": "https://search.naver.com/search.naver?" + query
        }
    }
    
    contents.append(content)

# JSON 형식 -> 문자열 변환
payload = {
    "template_object" : json.dumps(template)
}

# 카카오톡 보내기
res = requests.post(kakaotalk_template_url, data=payload, headers=kheaders)

if res.json().get('result_code') == 0:
    print('메시지를 성공적으로 보냈습니다.')
else:
    print('메시지를 성공적으로 보내지 못했습니다. 오류메시지 : ' + str(res.json()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-8e7cc2bb80eb> in <module>
#      67
#      68 #현재좌표의 격자구하기
# ---> 69 location=(mapToGrid(float(result.json().get('location').get('lat')), float(result.json().get('location').get('lng'))))
#      70
#      71 import requests
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
#google Geolocation API 사용
import os
import requests
from dotenv import load_dotenv
import math
load_dotenv(verbose=True)

LOCATION_API_KEY = os.getenv('LOCATION_API_KEY')

url = f'https://www.googleapis.com/geolocation/v1/geolocate?key=AIzaSyDqrO5yr7HQebIT62pWsNhF2xRGxynAuXQ'
data = {
    'considerIp': True,
}
#현재 좌표 구하기
result = requests.post(url, data)

print(result.text)
# Out:
# {
#   "error": {
#     "code": 404,
#     "message": "Requested entity was not found.",
#     "errors": [
#       {
#         "message": "Requested entity was not found.",
#         "domain": "global",
#         "reason": "notFound"
#       }
#     ],
#     "status": "NOT_FOUND"
#   }
# }

# %%
import json
import requests

def getFriendsList():
    header = {"Authorization": 'Bearer ' + KAKAO_TOKEN}
    url = "https://kapi.kakao.com/v1/api/talk/friends" #친구 정보 요청

    result = json.loads(requests.get(url, headers=header).text)

    friends_list = result.get("elements")
    friends_id = []

    print(requests.get(url, headers=header).text)
    print(friends_list)

    for friend in friends_list:
        friends_id.append(str(friend.get("uuid")))

        return friends_id

KAKAO_TOKEN = "4oRe8zd_k0iRena2m5X7xencbB7Ub0u3O7REHgo9dGkAAAF3FIpzgA" 

getFriendsList(524063)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-fa8b70684423> in <module>
#      21 KAKAO_TOKEN = "4oRe8zd_k0iRena2m5X7xencbB7Ub0u3O7REHgo9dGkAAAF3FIpzgA"
#      22
# ---> 23 getFriendsList(524063)
#
# TypeError: getFriendsList() takes 0 positional arguments but 1 was given

# %%
#https://kauth.kakao.com/oauth/authorize?client_id={REST_API 앱키를 입력하세요}&response_type=code&redirect_uri=https://localhost.com
import requests
import json

url = "https://kauth.kakao.com/oauth/token"

data = {
    "grant_type" : "authorization_code",
    "client_id" : "63435f91272f6e20e1cf693b27987220",
    "redirect_uri" : "https://localhost.com",
    "code"         : "BjtoBolvuq-6B2f0y07bpIm2Cy1XBM-VMXbVqx_mOSMto8PHLm3sQffbsDDgry68TNjqpQo9dRkAAAF3FIkebA"
    
}
response = requests.post(url, data=data)

tokens = response.json()

print(tokens)
# Out:
# {'access_token': '4oRe8zd_k0iRena2m5X7xencbB7Ub0u3O7REHgo9dGkAAAF3FIpzgA', 'token_type': 'bearer', 'refresh_token': '5KoldXItWQzsdk3Kv5mNx2W3IMFm9bFm2RTHgwo9dGkAAAF3FIpzfw', 'expires_in': 21599, 'scope': 'age_range account_email talk_message gender profile', 'refresh_token_expires_in': 5183999}
